# %%
import tensorflow as tf

# Load your model
model = tf.keras.models.load_model("face_mask_model.h5")

# Convert to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the tflite file
with open("face_mask_model.tflite", "wb") as f:
    f.write(tflite_model)

print("Model converted to TFLite successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\AFFANC~1\AppData\Local\Temp\tmp01cyqypq\assets
# INFO:tensorflow:Assets written to: C:\Users\AFFANC~1\AppData\Local\Temp\tmp01cyqypq\assets
# Saved artifact at 'C:\Users\AFFANC~1\AppData\Local\Temp\tmp01cyqypq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1648159895440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159896208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159895824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159899280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159899472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159898704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648159898512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161800848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161802576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161802384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161803344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161802768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161804304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161804112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161805072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161803920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161806416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161805840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161807376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161807184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161808144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161807568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161809104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161809296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161811024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1648161815056: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model converted to TFLite successfully!
